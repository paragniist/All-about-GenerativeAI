# %%
class MyClass:
    name = "NareshIT"

    def display(self):
        print(f"The vale is : {self.name}")

    def show(self):
        print("This is show method")

# %%
obj = MyClass()

obj.display()
# Out:
# The vale is : NareshIT

# %%
def test_param(a,b):
    print(a+b)

# %%
test_param(10,20)
# Out:
# 30
