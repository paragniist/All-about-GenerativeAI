# %%
# !pip install langchain
# !pip install langchain_community
# !pip install langchain_openai
import openai
import os
from langchain_community.llms import OpenAI
from langchain_openai import ChatOpenAI
from langchain.agents import load_tools

# %%
import os
os.environ['OPENAI_API_KEY'] = 'YOUR_OPENAI_API_KEY_HERE' # Replace with your actual OpenAI API Key
openai.api_key = os.getenv('OPENAI_API_KEY')
os.environ['SERPAPI_API_KEY'] = 'YOUR_SERPAPI_API_KEY_HERE' # Replace with your actual SERPAPI API Key

# %%
from langchain_openai import ChatOpenAI
from langchain_community.tools.llm_math.tool import LLMMathTool

llm = ChatOpenAI(temperature=0)
tools = [LLMMathTool(llm=llm)]

# %%
from langchain.agents import AgentExecutor
from langchain.agents.react.base import create_react_agent
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder

# Define the prompt for the agent
prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "You are a helpful assistant."),
        MessagesPlaceholder("chat_history"),
        ("human", "{input}"),
        MessagesPlaceholder("agent_scratchpad"),
    ]
)

# Create the agent
agent = create_react_agent(llm, tools, prompt)

# Create the agent executor
agent_executor = AgentExecutor(agent=agent, tools=tools, verbose=True)

# Run the agent with a math query
agent_executor.invoke({"input": "What is 1930 divided by 197?"})

# %%
agent= initialize_agent(tools, 11m, AgentType.ZERO_SHOT_REACT_DESCRIPTION, verbose=True)
agent.run("What's the difference in age between Lady Gaga and Taylor Swift?")

# %%
from langchain.tools.python.tool import PythonREPLTool
from langchain.python import PythonREPL
from langchain.agents.agent_toolkits import create_python_agent

# %%
agent = create_python_agent(
llm = llm
tool=PythonREPLTool(),
verbose True,
agent_type=AgentType.ZERO_SHOT_REACT_DESCRIPTION,
)

# %%
names = ["CHARLIE", "BOB", "ALICE", "DAVID", "EVELYN"]

# %%
agent.run(f"""
Convert this list into lowercase: (names). Then sort the list.
          """)
