# %%
import requests
import json

API_KEY = "AIzaSyCAm_6ojmORmw3vYsMYVe9QUPnJ6_7R3hw"
URL = "https://generativelanguage.googleapis.com/v1beta/openai/chat/completions"

headers = {
    "Authorization": f"Bearer {API_KEY}",
    "Content-Type": "application/json"
}

payload = {
    "model": "gemini-2.5-flash",
    "messages": [
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Explain how a computer works."}
    ]
}

response = requests.post(URL, headers=headers, json=payload)

# Parse response
data = response.json()

#print(data)
print(data["choices"][0]["message"]["content"])
# Out:
# A computer is essentially an electronic machine that takes data (input), processes it, stores the results, and then displays or acts on those results (output). It's designed to perform specific tasks, calculate, and solve problems at very high speeds.
#
# Let's break it down into its core components and how they work together:
#
# ### The Core Components (Hardware)
#
# Think of a computer like a super-organized office with specialized workers and storage.
#
# 1.  **CPU (Central Processing Unit) - The Brain:**
#     *   **What it does:** This is the primary component that performs calculations, executes instructions, and manages the flow of information. It's constantly fetching instructions, crunching numbers, and coordinating with other parts.
#     *   **Analogy:** The CEO or the head accountant who makes all the decisions and does the main calculations.
#
# 2.  **RAM (Random Access Memory) - The Short-Term Memory/Scratchpad:**
# ...

# %%
from openai import OpenAI

client = OpenAI(
    api_key="AIzaSyCAm_6ojmORmw3vYsMYVe9QUPnJ6_7R3hw",
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

response = client.chat.completions.create(
    model="gemini-2.5-flash",
    messages=[
      {"role": "system", "content": "You are a helpful assistant."},
      {"role": "user",   "content": "Explain how a computer works."}
    ]
)
print(response.choices[0].message.content)
# Out:
# At its core, a computer is an electronic machine that takes **input**, processes it, stores data, and produces **output**. It's built upon a few fundamental components that work together seamlessly.
#
# Think of it like an office with different specialized workers and storage facilities:
#
# ### The Main Components:
#
# 1.  **Central Processing Unit (CPU) - The Brain/Worker:**
#     *   **What it does:** The CPU is the "brain" of the computer. It performs all the calculations, executes instructions, and manages the flow of information. It's constantly crunching numbers, making decisions, and directing other components.
#     *   **How it works:** It fetches instructions from memory, decodes them, executes them (arithmetic, logic, control), and then stores the results back in memory. This cycle happens billions of times per second.
#
# 2.  **Random Access Memory (RAM) - The Workspace/Short-Term Memory:**
# ...

# %%
#pip install --upgrade google‑genai

from google import genai

client = genai.Client(api_key="AIzaSyACFMMNZHBQOxewsicPgp7m9N7S3e-QtzQ")

response = client.models.generate_content(
    model="gemini-2.5-flash", contents="Explain how AI works in a few words"
)
# 1. Access the complete text output (simplest way)
print(response.text)

# # 2. Correct way to iterate over the structured content parts
# # The candidates list contains the potential responses, and we usually look at the first one [0].
# # content contains the actual structure, and parts contains the individual text/function call blocks.
# for part in response.candidates[0].content.parts:
#     # Check if the part has a 'text' attribute (i.e., it's a text block)
#     if part.text:
#         print(part.text)
# Out:
# AI learns patterns from data to make decisions or predictions.

# %%
name ="prudvi"
print(f"my name is {name}")
# Out:
# my name is prudvi
