# %% [markdown]
# ## Generative Ai:
#
# generative ai refers to the class of artificial intelligence systems designed to create new content such as
# * Text
# * images
# * Audio
# * Video
# * Code
#
# based on patterns learned from existing data.
#
#
# ### Applications:
# * Text generation (eg Gpt, Gemini for conversation)
# * Images and art creation (eg DALL-E,Midjourney)
# * Music and Video synthesis
# * Code Generation(Eg Github Copilot)

# %% [markdown]
# ### Ai agents
#
# * An Ai agentiis an artificiial intelliigence system designed not just to generate information, but to take actions auutonomouusly in orer to achiieve specific goals.
# * Tarditional Generative Ai which focuses on creating content such as text, images, or coe an AI Agent can perceive its enviironment make ecisions and execute tasks.
# * Integration with tools and Apis : Often connects with external systems (like calendars browsers, Crms or databses) to perform practical fucntions.
#
# #### In simple terms:
# * Generative AI : Creates
# * Ai agents: Act also
#
# #### Example:
# * a gennratiive AI can write an email draft for you
# * an Ai agent can go further - write the email and send it to the right recipents at the rigth time after checking youur schedule and context.

# %% [markdown]
# Generative AI Project
#
# ➡️ Chatbot, resume builder, image app
#
# ➤ AI Agent System
#
# ➡️ Auto research bot, trading bot, scraper bot
#
# ➤ Agentic AI Platform
#
# ➡️ Startup-level product
# ➡️ SaaS
# ➡️ Autonomous AI system

# %% [markdown]
# Agentic AI = Multiple agents + planning + coordination.
# Example:
# 👉 “Plan my trip”
# System will:
#
# Find flights
#
# Compare prices
#
# Book hotel
#
# Make itinerary
#
# Manage budget
