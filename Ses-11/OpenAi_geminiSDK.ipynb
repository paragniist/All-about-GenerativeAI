# %% [markdown]
#  ### SDK - system design kit for Generative AI:

# %%
# pip install -- upgrade google-genai

from google import genai

client = genai.Client(api_key="AIzaSyA4o6hWrWcdVGW-J5hO_pqBGpn0D8vFq3s")

response = client.models.generate_content(
    model="gemini-2.5-flash", contents="Explain how AI works in simple terms.")

#1. Access the complete text outputs (simplest way
print(response.text)

# 2. Correct way to iterateover the strictured content parts 
## The candidate list contain sthe potential responses and we usually look at the first one, but you can also look at the other candidates if you want to see alternative responses.
## content contaiins the actual structure an dthe parts contains the indiividual text/ functiopn call blocks.
## for part in response.candidates [0].content.parts:
# check if the part has a text attribuute (i.e. it's a text block) and print it
# print(part.text)
# Out:
# Imagine AI as a very smart, but initially blank, **digital assistant** that learns to do tasks by looking at lots and lots of examples, much like a human does.
#
# Here's the breakdown in simple terms:
#
# 1.  **Data (The Lesson Book):**
#     *   AI starts with a huge amount of information, called **data**. Think of it as a massive lesson book filled with examples.
#     *   **Example:** If you want an AI to recognize cats, you'd show it thousands, even millions, of pictures – some with cats, some without. You'd tell it, "This is a cat," or "This is not a cat."
#
# 2.  **Learning (Studying the Book):**
#     *   The AI "studies" this data. It doesn't just memorize; it looks for **patterns, rules, and relationships** within the data.
# ...

# %%
## Open AI format

import json
import requests

API_KEY = "OpenAi key here"
URL = "openai api url here"

headers = {
    "Authorization": f"Bearer {API_KEY}",
    "Content-Type": "application/json"
}
payload = {
    "model ": "gemini-2.5-flash",
    "messages": [
        {
            "role": "system","content": "You are a helpful assistant."
        },
        {
            "role": "user","content": "Explain how AI works in simple terms."
        }
    ]
}   

response = requests.post(URL, headers=headers, data=json.dumps(payload))

#parse the response and print the generated content
data = response.json()

# print the generated content
print(data["choices"][0]["message"]["content"])

# %% [markdown]
# ## New updated open AI prompt method:

# %%
from openai import OpenAI
client = OpenAI()

response = client.responses.create(
    model="gpt-4.1",
    input="Explain how AI works"
)

print(response.output_text)

# %% [markdown]
# ## Gemini via OpenAi-Compatible interface:

# %%
from openai import OpenAI

client = OpenAI(
api_key= "AIzaSyA4o6hWrWcdVGW-J5hO_pqBGpn0D8vFq3s",
base_url = "https://generativelanguage.googleapis.com/v1beta/openai/")

response = client.chat.completions.create(
    model="gemini-2.5-flash",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Explain how AI works in simple terms."
        }
    ]
)
print(response.choices[0].message.content)
# Out:
# Imagine AI as a really smart student, but one who learns in a very specific way.
#
# Here's the simplified breakdown:
#
# 1.  **Feeding it Lots of Examples (Data):**
#     *   To teach a computer AI, you first give it *tons* of information – called "data."
#     *   **Example:** If you want an AI to recognize a cat, you show it thousands, even millions, of pictures of cats (and dogs, and trees, and cars, etc.), often labeling them ("this is a cat," "this is a dog").
#     *   **What the AI sees:** It doesn't "see" like we do. It sees patterns in the pixels, like arrangements of colors, shapes, textures, edges.
#
# 2.  **Learning the Patterns (Algorithms/Models):**
#     *   The AI uses a special program, called an **algorithm** (think of it as a set of instructions or a recipe), to sift through all that data.
#     *   Its goal is to find **patterns** and relationships within the data.
# ...

# %%
! pip show openai
# Out:
# Name: openai
# Version: 2.21.0
# Summary: The official Python library for the openai API
# Home-page:
# Author:
# Author-email: OpenAI <support@openai.com>
# License: Apache-2.0
# Location: /Users/ash/Desktop/GEN_AI/gemini/lib/python3.12/site-packages
# Requires: anyio, distro, httpx, jiter, pydantic, sniffio, tqdm, typing-extensions
# Required-by:
