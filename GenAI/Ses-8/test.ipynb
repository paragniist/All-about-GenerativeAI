# %% [markdown]
# ### Installation of python

# %% [markdown]
# ### Python environment (first_env) setup and activation

# %% [markdown]
# ash@Ashmeets-MacBook-Air Ses-8 % python3 -m venv first_env.
#
#
# ash@Ashmeets-MacBook-Air Ses-8 % first_env/bin/activate.
#
#
# zsh: permission denied: first_env/bin/activate.
#
#
# ash@Ashmeets-MacBook-Air Ses-8 % source first_env/bin/actiovate.
#
#
# source: no such file or directory: first_env/bin/actiovate.
#
#
# ash@Ashmeets-MacBook-Air Ses-8 % source first_env/bin/activate.
#
#
# (first_env) ash@Ashmeets-MacBook-Air Ses-8 % deactivate.
#
#
# ash@Ashmeets-MacBook-Air Ses-8 %
