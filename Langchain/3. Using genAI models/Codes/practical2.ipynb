# %%
# !pip install tiktoken
import tiktoken

encoding = tiktoken.get_encoding("cl100k_base")
token_text = "However, the current state of the art is largely experimental and impractical, with several obstacles to useful applications."
tokens = encoding.encode(token_text)
print(f"Tokens: {len(tokens)}")
# Out:
# ...
# Tokens: 22
