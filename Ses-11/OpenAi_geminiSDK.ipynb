# %% [markdown]
#  ### SDK - system design kit for Generative AI:

# %%
# pip install -- upgrade google-genai

from google import genai

client = genai.Client(api_key="YOUR_API_KEY_HERE")

response = client.models.generate_content(
    model="gemini-2.5-flash", contents="Explain how AI works in simple terms.")

#1. Access the complete text outputs (simplest way
print(response.text)

# 2. Correct way to iterateover the strictured content parts 
## The candidate list contain sthe potential responses and we usually look at the first one, but you can also look at the other candidates if you want to see alternative responses.
## content contaiins the actual structure an dthe parts contains the indiividual text/ functiopn call blocks.
## for part in response.candidates [0].content.parts:
# check if the part has a text attribuute (i.e. it's a text block) and print it
# print(part.text)
# Out:
# Imagine AI as a really smart student, but instead of a brain, it has a powerful computer. Here's how it generally works:
#
# 1.  **Learning from Examples (Training):**
#     *   **Data, Data, Data!** Just like a student needs textbooks and examples, AI needs a huge amount of information (called "data"). This could be millions of pictures, text documents, sounds, numbers, or videos.
#     *   **Finding Patterns:** The AI then "studies" this data. It's not *thinking* like a human, but it's really good at finding patterns and relationships that even a human might miss. For example, if you show it a million pictures of cats and dogs, it starts to figure out what visual features usually mean "cat" and what features usually mean "dog."
#     *   **Building a Model (Learning):** Based on these patterns, the AI builds an internal "model" or a set of rules. This model is its learned knowledge. It doesn't write down a rule like "all cats have pointy ears," but rather a complex mathematical representation of what makes a cat *statistically probable*.
#     *   **Feedback & Refinement:** If the AI makes a mistake (e.g., identifies a cat as a dog), a human might correct it, or it might be programmed to learn from its own errors. It then adjusts its model to do better next time, much like a student learns from getting a question wrong.
#
# 2.  **Making Decisions (Inference):**
#     *   Once the AI has been trained and has its "model," it can be put to work.
#     *   **New Input:** You give it something new it hasn't seen before. For example, a new picture, a new sentence, or a new piece of data.
#     *   **Apply Rules:** The AI takes this new input and runs it through its learned model (its "rules").
#     *   **Output/Prediction:** It then makes a prediction or a decision based on what it learned. "This new picture is 98% likely to be a cat," or "Based on this text, here's a relevant answer," or "This person is likely to buy product X."
#
# **Think of it like this:**
#
# *   **Training:** You show a child thousands of pictures and tell them "This is a cat," "This is a dog." Eventually, the child learns to tell the difference.
# *   **Working:** Later, you show the child a new picture, and they can tell you if it's a cat or a dog.
#
# **Key Concepts in Simple Terms:**
#
# *   **Machine Learning (ML):** This is the most common way AI learns. It's the process where computers learn from data without being explicitly programmed for every single task.
# *   **Neural Networks:** These are a type of ML system inspired by the human brain. They're good at finding very complex patterns, especially in things like images, sound, and language.
# *   **Deep Learning:** This is a more advanced type of neural network with many "layers," allowing it to learn even more intricate patterns. This is behind many of the latest AI breakthroughs (like ChatGPT, self-driving cars, advanced image recognition).
#
# **What AI is NOT (yet):**
#
# *   It's not truly conscious.
# *   It doesn't "feel" emotions or truly "understand" in the human sense.
# *   It's a powerful tool that excels at finding patterns and making predictions based on the data it was trained on.

# %%
## Open AI format

import json
import requests

API_KEY = "OpenAi key here"
URL = "openai api url here"

headers = {
    "Authorization": f"Bearer {API_KEY}",
    "Content-Type": "application/json"
}
payload = {
    "model ": "gemini-2.5-flash",
    "messages": [
        {
            "role": "system","content": "You are a helpful assistant."
        },
        {
            "role": "user","content": "Explain how AI works in simple terms."
        }
    ]
}   

response = requests.post(URL, headers=headers, data=json.dumps(payload))

#parse the response and print the generated content
data = response.json()

# print the generated content
print(data["choices"][0]["message"]["content"])

# %% [markdown]
# ## New updated open AI prompt method:

# %%
from openai import OpenAI
client = OpenAI()

response = client.responses.create(
    model="gpt-4.1",
    input="Explain how AI works"
)

print(response.output_text)

# %% [markdown]
# ## Gemini via OpenAi-Compatible interface:

# %%
from openai import OpenAI

client = OpenAI(
api_key= "OpenAI key here",
base_url = "https://generativelanguage.googleapis.com/v1beta/openai/")

response = client.chat.completions.create(
    model="gemini-2.5-flash",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Explain how AI works in simple terms."
        }
    ]
)
print(response.choices[0].message.content)
# Out:
# Imagine AI as a very smart student that learns from experience, rather than being told every single thing to do.
#
# Here's how it generally works in simple terms:
#
# 1.  **Data is the Food for AI:**
#     *   Just like a student needs textbooks and examples, AI needs **data**. This data can be anything: millions of pictures, thousands of hours of speech, countless lines of text, or numbers from sales records.
#     *   The more and better the data, the smarter the AI can become.
#
# 2.  **Finding Patterns (The Learning Part):**
#     *   The AI is given a task, for example, identifying cats in pictures.
#     *   We show it *thousands* of pictures, some with cats (labeled "cat") and some without (labeled "not a cat").
#     *   The AI then uses complex mathematical techniques (think of them as super-smart pattern detectors) to find **common features** in all the "cat" pictures. It might notice shapes, textures, sizes, and colors that usually belong to a cat.
#     *   It tries to "figure out" what makes a cat a cat, without us explicitly telling it "a cat has pointy ears, whiskers, and a tail."
#
# 3.  **Trial and Error (Getting Better):**
#     *   Initially, the AI will make lots of mistakes. It might think a dog is a cat, or a fluffy slipper is a cat.
#     *   When it makes a mistake, we tell it ("No, that was actually a dog!"). This **feedback** helps the AI adjust its internal settings and refine its understanding of what a cat looks like.
#     *   It keeps doing this over and over, making small adjustments with each correct or incorrect guess, until it gets really good at recognizing cats. This process is called **training**.
#
# 4.  **Making Predictions/Decisions (Using What It Learned):**
#     *   Once the AI is well-trained, you can show it a **brand new picture** it's never seen before.
#     *   Based on all the patterns it learned during training, it can now confidently say, "This is a cat!" or "This is not a cat!"
#     *   It's essentially applying its learned knowledge to new situations.
#
# **In a Nutshell:**
#
# AI is about teaching computers to **learn from data and experience**, recognize patterns, and then use that learned knowledge to make decisions or predictions on new information, rather than just blindly following pre-programmed rules.
#
# **Think of it like this:**
#
# *   **A regular computer program:** You write a recipe with exact steps for baking a cake. If anything changes (a new ingredient, oven breaks), it can't adapt.
# *   **AI:** You show it thousands of pictures of delicious cakes, tell it what makes them good (and bad), and let it practice baking. Eventually, it learns what makes a good cake and can even invent new recipes or adjust if an ingredient is missing.

# %%
! pip show openai
# Out:
# Name: openai
# Version: 2.21.0
# Summary: The official Python library for the openai API
# Home-page:
# Author:
# Author-email: OpenAI <support@openai.com>
# License: Apache-2.0
# Location: /Users/ash/Desktop/GEN_AI/gemini/lib/python3.12/site-packages
# Requires: anyio, distro, httpx, jiter, pydantic, sniffio, tqdm, typing-extensions
# Required-by:
